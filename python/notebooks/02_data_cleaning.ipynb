# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df1=pd.read_csv("../data/raw/olist_customers_dataset.csv")
df2=pd.read_csv("../data/raw/olist_orders_dataset.csv")
df3=pd.read_csv("../data/raw/olist_order_items_dataset.csv")
df4=pd.read_csv("../data/raw/olist_order_payments_dataset.csv")
df5=pd.read_csv("../data/raw/olist_products_dataset.csv")
df6=pd.read_csv("../data/raw/olist_order_reviews_dataset.csv")
df7=pd.read_csv("../data/raw/olist_sellers_dataset.csv")
df8=pd.read_csv("../data/raw/olist_geolocation_dataset.csv")
df9=pd.read_csv("../data/raw/product_category_name_translation.csv")

# %%
print("Before:", df8.shape)

df8_clean = df8.drop_duplicates()

print("After:", df8_clean.shape)
print("Duplicates Removed:", df8.shape[0] - df8_clean.shape[0])

# %%
df8_clean.duplicated().sum()

# %%
df8_clean.to_csv("../data/processed/geolocation_clean.csv", index=False)

# %% [markdown]
# # Geolocation Cleaning
#
# ### Problem
# The geolocation dataset contained duplicate records.
#
# ### Solution
# Removed duplicate rows using pandas `drop_duplicates()`.
#
# ### Result
# Created a cleaned dataset with only unique records for downstream analysis.
